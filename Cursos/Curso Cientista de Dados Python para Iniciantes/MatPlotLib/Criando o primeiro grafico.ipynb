# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
gas = pd.read_csv('Tabelas/gas.csv')
gas

# %%
plt.plot(gas['Year'], gas['Australia'])  #Seleciona na tabela paises a serem consultados 
plt.plot(gas['Year'], gas['Italy'])
plt.plot(gas['Year'], gas['USA'])

plt.show() #Mostra o grafico
